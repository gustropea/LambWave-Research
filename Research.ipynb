# %% [markdown]
# # Timing Results:
# ## Cubed Sphere: Patchsize (12x12)

# %% [markdown]
# <table>
# <thead>
#     <tr>
#         <th><center><strong><h2>Non Subcycling</h2></strong></center></th>
#         <th><center><strong><h2>Subcycling</h2></strong></center></th>
#     <tr>
# </thead>
# <tbody>
#     <tr>
#         <td>
#             <center><h3><strong>Min Level:</strong> 0</h3></center>
#             <center><h3><strong>Max Level:</strong> 0</h3></center>
#             <video src="plots/cubed/nonsubcycle/0_0/0_0.mp4" width="480" controls></video>
#             <center><h3><strong>Time Results:</strong></h3></center>
#             <p>Statistics for   WALLTIME<br/>
# [libsc]    Global number of values:       4<br>
# [libsc]    Mean value (std. dev.):           0.110795 (3.11e-05 = 0.028%)<br/>
# [libsc]    Minimum attained at rank       2: 0.110776<br/>
# [libsc]    Maximum attained at rank       3: 0.110849
# [libsc] Procs 4 advance 73 0.024668 exchange 75 0.005355 regrid 73 0 9.6e-05</br>
# [libsc] Max/P 4 advance 73 0.039107 exchange 75 0.006561 regrid 73 0 0.000182</p>
#         </td>
#         <td>
#             <center><h3><strong>Min Level:</strong> 0</h3></center>
#             <center><h3><strong>Max Level:</strong> 0</h3></center>
#             <video src="plots/cubed/subcycle/0_0/0_0.mp4" width="480" controls></video>
#              <center><h3><strong>Time Results:</strong></h3></center>
#             <p>Statistics for   WALLTIME<br/>
# [libsc]    Global number of values:       4<br/>
# [libsc]    Mean value (std. dev.):           0.0907925 (9.55e-06 = 0.0105%)<br/>
# [libsc]    Minimum attained at rank       1: 0.090782<br/>
# [libsc]    Maximum attained at rank       0: 0.090803<br/>
# [libsc] Procs 4 advance 73 0.0208332 exchange 75 0.005672 regrid 73 0 5.675e-05<br/>
# [libsc] Max/P 4 advance 73 0.029523 exchange 75 0.006989 regrid 73 0 6e-05</p>
#         </td>
#     </tr>
#         <tr>
#         <td>
#             <center><h3><strong>Min Level:</strong> 0</h3></center>
#             <center><h3><strong>Max Level:</strong> 1</h3></center>
#             <video src="plots/cubed/nonsubcycle/0_1/0_1.mp4" width="480" controls></video>
#             <center><h3><strong>Time Results:</strong></h3></center>
#             <p>Statistics for   WALLTIME<br/>
# [libsc]    Global number of values:       4<br>
# [libsc]    Mean value (std. dev.):           0.398914 (0.000162 = 0.0406%)<br/>
# [libsc]    Minimum attained at rank       2: 0.398801<br>
# [libsc]    Maximum attained at rank       3: 0.399193<br>
# [libsc] Procs 4 advance 69 0.131255 exchange 145 0.0286053 regrid 69 5 0.0125772 <br/>
# [libsc] Max/P 4 advance 69 0.145136 exchange 145 0.033675 regrid 69 5 0.017795</p>
#         </td>
#         <td>
#             <center><h3><strong>Min Level:</strong> 0</h3></center>
#             <center><h3><strong>Max Level:</strong> 1</h3></center>
#             <video src="plots/cubed/subcycle/0_1/0_1.mp4" width="480" controls></video>
#             <center><h3><strong>Time Results:</strong></h3></center>
#             <p>Statistics for   WALLTIME<br/>
# [libsc]    Global number of values:       4<br/>
# [libsc]    Mean value (std. dev.):           0.380555 (9.03e-06 = 0.00237%)<br/>
# [libsc]    Minimum attained at rank       2: 0.380546<br/>
# [libsc]    Maximum attained at rank       0: 0.380565<br/>
# [libsc] Procs 4 advance 71 0.128188 exchange 149 0.028487 regrid 71 5 0.0122913<br/>
# [libsc] Max/P 4 advance 71 0.139532 exchange 149 0.032759 regrid 71 5 0.017901</p>
#         </td>
#     </tr>
#         <tr>
#         <td>
#             <center><h3><strong>Min Level:</strong> 0</h3></center>
#             <center><h3><strong>Max Level:</strong> 2</h3></center>
#             <video src="plots/cubed/nonsubcycle/0_2/0_2.mp4" width="480" controls></video>
#             <center><h3><strong>Time Results:</strong></h3></center>
#             <p>Statistics for   WALLTIME<br/>
# [libsc]    Global number of values:       4<br/>
# [libsc]    Mean value (std. dev.):           1.72581 (0.00148 = 0.0855%)<br/>
# [libsc]    Minimum attained at rank       2: 1.72495<br/>
# [libsc]    Maximum attained at rank       3: 1.72837<br/>
# [libsc] Procs 4 advance 68 0.737626 exchange 320 0.179584 regrid 68 46 0.141154<br/>
# [libsc] Max/P 4 advance 68 0.80424 exchange 320 0.220831 regrid 68 46 0.167318<br/></p>
#         </td>
#         <td>
#             <center><h3><strong>Min Level:</strong> 0</h3></center>
#             <center><h3><strong>Max Level:</strong> 2</h3></center>
#             <video src="plots/cubed/subcycle/0_2/0_2.mp4" width="480" controls></video>
#             <center><h3><strong>Time Results:</strong></h3></center>
#             <p>Statistics for   WALLTIME<br/>
# [libsc]    Global number of values:       4<br/>
# [libsc]    Mean value (std. dev.):           1.77181 (3.81e-06 = 0.000215%)<br/>
# [libsc]    Minimum attained at rank       3: 1.77181<br/>
# [libsc]    Maximum attained at rank       0: 1.77182<br/>
# [libsc] Procs 4 advance 69 0.699094 exchange 326 0.18535 regrid 69 48 0.150556<br/>
# [libsc] Max/P 4 advance 69 0.75466 exchange 326 0.189761 regrid 69 48 0.1645</p>
#         </td>
#     </tr>
#     <tr>
#         <td>
#             <center><h3><strong>Min Level:</strong> 0</h3></center>
#             <center><h3><strong>Max Level:</strong> 3</h3></center>
#             <video src="plots/cubed/nonsubcycle/0_3/0_3.mp4" width="480" controls></video>
#             <center><h3><strong>Time Results:</strong></h3></center>
#             <p>Statistics for   WALLTIME<br/>
# [libsc]    Global number of values:       4<br/>
# [libsc]    Mean value (std. dev.):           10.3418 (0.000369 = 0.00357%)<br/>
# [libsc]    Minimum attained at rank       3: 10.3414<br/>
# [libsc]    Maximum attained at rank       0: 10.3421<br/>
# [libsc] Procs 4 advance 68 6.95129 exchange 601 1.08682 regrid 68 55 0.50267 <br/>
# [libsc] Max/P 4 advance 68 7.15516 exchange 601 1.14536 regrid 68 55 0.545689</p>
#         </td>
#         <td>
#             <center><h3><strong>Min Level:</strong> 0</h3></center>
#             <center><h3><strong>Max Level:</strong> 3</h3></center>
#             <video src="plots/cubed/subcycle/0_3/0_3.mp4" width="480" controls></video>
#             <center><h3><strong>Time Results:</strong></h3></center>
#             <p>Statistics for   WALLTIME<br/>
# [libsc]    Global number of values:       4<br/>
# [libsc]    Mean value (std. dev.):           10.0708 (9.79e-05 = 0.000972%)<br/>
# [libsc]    Minimum attained at rank       0: 10.0706<br/>
# [libsc]    Maximum attained at rank       1: 10.0709<br/>
# [libsc] Procs 4 advance 68 6.63115 exchange 600 1.10313 regrid 68 54 0.511509<br/>
# [libsc] Max/P 4 advance 68 6.86632 exchange 600 1.2001 regrid 68 54 0.571052</p>
#         </td>
#     </tr>
#         <tr>
#         <td>
#             <center><h3><strong>Min Level:</strong> 0</h3></center>
#             <center><h3><strong>Max Level:</strong> 4</h3></center>
#             <video src="plots/cubed/nonsubcycle/0_4/0_4.mp4" width="480" controls></video>
#             <center><h3><strong>Time Results:</strong></h3></center>
#             <p>Statistics for   WALLTIME<br/>
# [libsc]    Global number of values:       4<br/>
# [libsc]    Mean value (std. dev.):           46.3309 (0.00116 = 0.0025%)<br/>
# [libsc]    Minimum attained at rank       0: 46.3289<br/>
# [libsc]    Maximum attained at rank       1: 46.3316<br/>
# [libsc] Procs 4 advance 67 35.5448 exchange 1140 4.84473 regrid 67 66 1.51378<br/>
# [libsc] Max/P 4 advance 67 36.4115 exchange 1140 5.07344 regrid 67 66 1.72658</p>
#         </td>
#         <td>
#             <center><h3><strong>Min Level:</strong> 0</h3></center>
#             <center><h3><strong>Max Level:</strong> 4</h3></center>
#             <video src="plots/cubed/subcycle/0_4/0_4.mp4" width="480" controls></video>
#             <center><h3><strong>Time Results:</strong></h3></center>
#             <p>Statistics for   WALLTIME<br/>
# [libsc]    Global number of values:       4<br/>
# [libsc]    Mean value (std. dev.):           43.7178 (0.00577 = 0.0132%)<br>
# [libsc]    Minimum attained at rank       0: 43.7078<br/>
# [libsc]    Maximum attained at rank       2: 43.7212<br/>
# [libsc] Procs 4 advance 68 31.2684 exchange 1158 4.74198 regrid 68 68 1.50673<br/>
# [libsc] Max/P 4 advance 68 32.2584 exchange 1158 4.96959 regrid 68 68 1.78898</p>
#         </td>
#     </tr>
#         <tr>
#         <td>
#             <center><h3><strong>Min Level:</strong> 0</h3></center>
#             <center><h3><strong>Max Level:</strong> 5</h3></center>
#             <video src="plots/cubed/nonsubcycle/0_5/0_5.mp4" width="480" controls></video>
#             <center><h3><strong>Time Results:</strong></h3></center>
#             <p>Statistics for   WALLTIME<br/>
# [libsc]    Global number of values:       4<br/>
# [libsc]    Mean value (std. dev.):           212.672 (0.000736 = 0.000346%)<br/>
# [libsc]    Minimum attained at rank       0: 212.671<br/>
# [libsc]    Maximum attained at rank       1: 212.672<br/>
# [libsc] Procs 4 advance 67 175.202 exchange 2212 21.0061 regrid 66 66 3.97773<br/>
# [libsc] Max/P 4 advance 67 179.55 exchange 2212 21.6646 regrid 66 66 4.46486</p>
#         </td>
#         <td>
#             <center><h3><strong>Min Level:</strong> 0</h3></center>
#             <center><h3><strong>Max Level:</strong> 5</h3></center>
#             <video src="plots/cubed/subcycle/0_5/0_5.mp4" width="480" controls></video>
#             <center><h3><strong>Time Results:</strong></h3></center>
#             <p>Statistics for   WALLTIME<br/>
# [libsc]    Global number of values:       4<br/>
# [libsc]    Mean value (std. dev.):           190.403 (0.000211 = 0.000111%)<br/>
# [libsc]    Minimum attained at rank       1: 190.403<br/>
# [libsc]    Maximum attained at rank       0: 190.403<br/>
# [libsc] Procs 4 advance 68 148.23 exchange 2246 19.6819 regrid 68 68 4.06711<br/>
# [libsc] Max/P 4 advance 68 152.356 exchange 2246 20.4824 regrid 68 68 4.8006</p>
#         </td>
#     </tr>
# </tbody>
# </table>

# %% [markdown]
# ## Pillow Sphere: Patchsize (12x12)

# %% [markdown]
# <table>
# <thead>
#     <tr>
#         <th><center><strong><h2>Non Subcycling</h2></strong></center></th>
#         <th><center><strong><h2>Subcycling</h2></strong></center></th>
#     <tr>
# </thead>
# <tbody>
#     <tr>
#         <td>
#             <center><h3><strong>Min Level:</strong> 0</h3></center>
#             <center><h3><strong>Max Level:</strong> 0</h3></center>
#             <video src="plots/pillow/nonsubcycle/0_0/0_0.mp4" width="480" controls></video>
#             <center><h3><strong>Time Results:</strong></h3></center>
#             <p>Statistics for   WALLTIME<br/>
# [libsc]    Global number of values:       4<br/>
# [libsc]    Mean value (std. dev.):           0.0222663 (7.46e-06 = 0.0335%)<br/>
# [libsc]    Minimum attained at rank       0: 0.022261<br/>
# [libsc]    Maximum attained at rank       1: 0.022279<br/>
# [libsc] Procs 4 advance 41 0.003946 exchange 43 0.000925 regrid 41 0 2.4e-05<br/>
# [libsc] Max/P 4 advance 41 0.007792 exchange 43 0.001771 regrid 41 0 2.8e-05</p>
#         </td>
#         <td>
#             <center><h3><strong>Min Level:</strong> 0</h3></center>
#             <center><h3><strong>Max Level:</strong> 0</h3></center>
#             <video src="plots/pillow/subcycle/0_0/0_0.mp4" width="480" controls></video>
#             <center><h3><strong>Time Results:</strong></h3></center>
#             <p>Statistics for   WALLTIME<br/>
# [libsc]    Global number of values:       4<br/>
# [libsc]    Mean value (std. dev.):           0.022804 (6.44e-06 = 0.0282%)<br/>
# [libsc]    Minimum attained at rank       2: 0.022799<br/>
# [libsc]    Maximum attained at rank       3: 0.022815<br/>
# [libsc] Procs 4 advance 41 0.00368125 exchange 43 0.00089725 regrid 41 0 2.225e-05<br/>
# [libsc] Max/P 4 advance 41 0.007302 exchange 43 0.001725 regrid 41 0 2.4e-05</p>
#         </td>
#     </tr>
#         <tr>
#         <td>
#             <center><h3><strong>Min Level:</strong> 0</h3></center>
#             <center><h3><strong>Max Level:</strong> 1</h3></center>
#             <video src="plots/pillow/nonsubcycle/0_1/0_1.mp4" width="480" controls></video>
#             <center><h3><strong>Time Results:</strong></h3></center>
#             <p>Statistics for   WALLTIME<br/>
# [libsc]    Global number of values:       4<br/>
# [libsc]    Mean value (std. dev.):           0.257684 (2.76e-05 = 0.0107%)<br/>
# [libsc]    Minimum attained at rank       3: 0.257665<br/>
# [libsc]    Maximum attained at rank       1: 0.257732<br/>
# [libsc] Procs 4 advance 42 0.028562 exchange 86 0.00571175 regrid 42 0 0.00145725<br/>
# [libsc] Max/P 4 advance 42 0.057838 exchange 86 0.011313 regrid 42 0 0.003962</p>
#         </td>
#         <td>
#             <center><h3><strong>Min Level:</strong> 0</h3></center>
#             <center><h3><strong>Max Level:</strong> 1</h3></center>
#             <video src="plots/pillow/subcycle/0_1/0_1.mp4" width="480" controls></video>
#             <center><h3><strong>Time Results:</strong></h3></center>
#             <p>Statistics for   WALLTIME<br/>
# [libsc]    Global number of values:       4<br/>
# [libsc]    Mean value (std. dev.):           0.110513 (0.000199 = 0.18%)<br/>
# [libsc]    Minimum attained at rank       3: 0.110364<br/>
# [libsc]    Maximum attained at rank       2: 0.110855<br/>
# [libsc] Procs 4 advance 42 0.0288543 exchange 86 0.0064 regrid 42 0 0.001445<br/>
# [libsc] Max/P 4 advance 42 0.057632 exchange 86 0.014189 regrid 42 0 0.0039</p>
#         </td>
#     </tr>
#         <tr>
#         <td>
#             <center><h3><strong>Min Level:</strong> 0</h3></center>
#             <center><h3><strong>Max Level:</strong> 2</h3></center>
#             <video src="plots/pillow/nonsubcycle/0_2/0_2.mp4" width="480" controls></video>
#             <center><h3><strong>Time Results:</strong></h3></center>
#             <p>Statistics for   WALLTIME<br/>
# [libsc]    Global number of values:       4<br/>
# [libsc]    Mean value (std. dev.):           0.529281 (0.00366 = 0.692%)<br/>
# [libsc]    Minimum attained at rank       3: 0.527166<br/>
# [libsc]    Maximum attained at rank       1: 0.535621<br/>
# [libsc] Procs 4 advance 43 0.182089 exchange 179 0.040186 regrid 43 5 0.0202702<br/>
# [libsc] Max/P 4 advance 43 0.226205 exchange 179 0.04825 regrid 43 5 0.025809</p>
#         </td>
#         <td>
#             <center><h3><strong>Min Level:</strong> 0</h3></center>
#             <center><h3><strong>Max Level:</strong> 2</h3></center>
#             <video src="plots/pillow/subcycle/0_2/0_2.mp4" width="480" controls></video>
#             <center><h3><strong>Time Results:</strong></h3></center>
#             <p>Statistics for   WALLTIME<br/>
# [libsc]    Global number of values:       4<br/>
# [libsc]    Mean value (std. dev.):           0.412615 (4.6e-06 = 0.00112%)<br/>
# [libsc]    Minimum attained at rank       1: 0.412607<br/>
# [libsc]    Maximum attained at rank       2: 0.412619<br/>
# [libsc] Procs 4 advance 43 0.171409 exchange 179 0.042525 regrid 43 5 0.020429<br/>
# [libsc] Max/P 4 advance 43 0.204912 exchange 179 0.047204 regrid 43 5 0.023405</p>
#         </td>
#     </tr>
#     <tr>
#         <td>
#             <center><h3><strong>Min Level:</strong> 0</h3></center>
#             <center><h3><strong>Max Level:</strong> 3</h3></center>
#             <video src="plots/pillow/nonsubcycle/0_3/0_3.mp4" width="480" controls></video>
#             <center><h3><strong>Time Results:</strong></h3></center>
#             <p>Statistics for   WALLTIME<br/>
# [libsc]    Global number of values:       4<br/>
# [libsc]    Mean value (std. dev.):           2.85501 (3.19e-06 = 0.000112%)<br/>
# [libsc]    Minimum attained at rank       3: 2.85501<br/>
# [libsc]    Maximum attained at rank       1: 2.85502<br/>
# [libsc] Procs 4 advance 43 1.79508 exchange 351 0.271723 regrid 43 5 0.102092<br/>
# [libsc] Max/P 4 advance 43 1.8064 exchange 351 0.281491 regrid 43 5 0.12236</p>
#         </td>
#         <td>
#             <center><h3><strong>Min Level:</strong> 0</h3></center>
#             <center><h3><strong>Max Level:</strong> 3</h3></center>
#             <video src="plots/pillow/subcycle/0_3/0_3.mp4" width="480" controls></video>
#             <center><h3><strong>Time Results:</strong></h3></center>
#             <p>Statistics for   WALLTIME<br/>
# [libsc]    Global number of values:       4<br/>
# [libsc]    Mean value (std. dev.):           2.84045 (9.36e-05 = 0.00329%)<br/>
# [libsc]    Minimum attained at rank       3: 2.84039<br/>
# [libsc]    Maximum attained at rank       2: 2.84061<br/>
# [libsc] Procs 4 advance 43 1.80987 exchange 351 0.28033 regrid 43 5 0.0990107<br/>
# [libsc] Max/P 4 advance 43 1.82049 exchange 351 0.296864 regrid 43 5 0.116655</p>
#         </td>
#     </tr>
#         <tr>
#         <td>
#             <center><h3><strong>Min Level:</strong> 0</h3></center>
#             <center><h3><strong>Max Level:</strong> 4</h3></center>
#             <video src="plots/pillow/nonsubcycle/0_4/0_4.mp4" width="480" controls></video>
#             <center><h3><strong>Time Results:</strong></h3></center>
#             <p>Statistics for   WALLTIME<br/>
# [libsc]    Global number of values:       4<br/>
# [libsc]    Mean value (std. dev.):           15.3083 (1.05e-05 = 6.84e-05%)<br/>
# [libsc]    Minimum attained at rank       3: 15.3083<br/>
# [libsc]    Maximum attained at rank       1: 15.3084<br/>
# [libsc] Procs 4 advance 43 11.1043 exchange 732 1.54663 regrid 43 42 0.640888<br/>
# [libsc] Max/P 4 advance 43 11.1697 exchange 732 1.64349 regrid 43 42 0.7064</p>
#         </td>
#         <td>
#             <center><h3><strong>Min Level:</strong> 0</h3></center>
#             <center><h3><strong>Max Level:</strong> 4</h3></center>
#             <video src="plots/pillow/subcycle/0_4/0_4.mp4" width="480" controls></video>
#             <center><h3><strong>Time Results:</strong></h3></center>
#             <p>Statistics for   WALLTIME<br/>
# [libsc]    Global number of values:       4<br/>
# [libsc]    Mean value (std. dev.):           14.7363 (0.000175 = 0.00119%)<br/>
# [libsc]    Minimum attained at rank       1: 14.736<br/>
# [libsc]    Maximum attained at rank       2: 14.7364<br/>
# [libsc] Procs 4 advance 43 10.3268 exchange 732 1.55687 regrid 43 42 0.6529<br/>
# [libsc] Max/P 4 advance 43 10.4779 exchange 732 1.68305 regrid 43 42 0.74362</p>
#         </td>
#     </tr>
#         <tr>
#         <td>
#             <center><h3><strong>Min Level:</strong> 0</h3></center>
#             <center><h3><strong>Max Level:</strong> 5</h3></center>
#             <video src="plots/pillow/nonsubcycle/0_5/0_5.mp4" width="480" controls></video>
#             <center><h3><strong>Time Results:</strong></h3></center>
#             <p>Statistics for   WALLTIME<br/>
# [libsc]    Global number of values:       4<br/>
# [libsc]    Mean value (std. dev.):           81.4905 (2.52e-06 = 3.1e-06%)<br/>
# [libsc]    Minimum attained at rank       3: 81.4905<br/>
# [libsc]    Maximum attained at rank       1: 81.4905<br/>
# [libsc] Procs 4 advance 43 62.8117 exchange 1421 7.75507 regrid 43 43 2.02978<br/>
# [libsc] Max/P 4 advance 43 63.3548 exchange 1421 7.96475 regrid 43 43 2.24918</p>
#         </td>
#         <td>
#             <center><h3><strong>Min Level:</strong> 0</h3></center>
#             <center><h3><strong>Max Level:</strong> 5</h3></center>
#             <video src="plots/pillow/subcycle/0_5/0_5.mp4" width="480" controls></video>
#             <center><h3><strong>Time Results:</strong></h3></center>
#             <p>Statistics for   WALLTIME<br/>
# [libsc]    Global number of values:       4<br/>
# [libsc]    Mean value (std. dev.):           62.828 (0.000133 = 0.000212%)<br/>
# [libsc]    Minimum attained at rank       3: 62.8279<br/>
# [libsc]    Maximum attained at rank       2: 62.8282<br/>
# [libsc] Procs 4 advance 43 48.289 exchange 1421 6.5382 regrid 43 43 1.87255<br/>
# [libsc] Max/P 4 advance 43 48.8028 exchange 1421 6.77213 regrid 43 43 2.08043></p>
#         </td>
#     </tr>
# </tbody>
# </table>

# %% [markdown]
# # Fdisk

# %%
# %%latex
# \begin{align*}
# \frac{(xp)^{2}}{a^{2}}+\frac{(yp)^{2}}{b^{2}}+\frac{(zp)^{2}}{c^{2}}&=1\\
# \frac{(xp-xc)^{2}}{a^{2}}+\frac{(yp-yc)^{2}}{b^{2}}&=r^{2}+\frac{(zp-zc)^{2}}{c^{2}}\\
# \end{align*}
#
# After combining the two equations:
#
# \begin{align}
#     \frac{2(xc)(xp)}{a^{2}}+\frac{2(yc)(yp)}{b^{2}}+\frac{2(zc)(zp)}{c^{2}} = \left(1- r^{2}\right)+\left(\frac{(xc)^{2}}{a^{2}}+\frac{(yc)^{2}}{b^{2}}+\frac{(zc)^{2}}{c^{2}}\right)
# \end{align}
#
# There is no intersection if
# $$\left(\frac{(xc)^{2}}{a^{2}}+\frac{(yc)^{2}}{b^{2}}+\frac{(zc)^{2}}{c^{2}}\right)>\left(1+r\right)^{2}$$
# Out:
# \begin{align*}
# \frac{(xp)^{2}}{a^{2}}+\frac{(yp)^{2}}{b^{2}}+\frac{(zp)^{2}}{c^{2}}&=1\\
# \frac{(xp-xc)^{2}}{a^{2}}+\frac{(yp-yc)^{2}}{b^{2}}&=r^{2}+\frac{(zp-zc)^{2}}{c^{2}}\\
# \end{align*}
#
# After combining the two equations:
#
# \begin{align}
#     \frac{2(xc)(xp)}{a^{2}}+\frac{2(yc)(yp)}{b^{2}}+\frac{2(zc)(zp)}{c^{2}} = \left(1- r^{2}\right)+\left(\frac{(xc)^{2}}{a^{2}}+\frac{(yc)^{2}}{b^{2}}+\frac{(zc)^{2}}{c^{2}}\right)
# \end{align}
#
# There is no intersection if
# $$\left(\frac{(xc)^{2}}{a^{2}}+\frac{(yc)^{2}}{b^{2}}+\frac{(zc)^{2}}{c^{2}}\right)>\left(1+r\right)^{2}$$
